# %%
import pandas as pd
training_data = pd.read_csv('/content/train_features.csv')

# %%
training_labels = pd.read_csv('/content/train_labels.csv')

# %%
feature_metadata = pd.read_json('/content/feature_classification_input.json')

# %%
import json


json_data = '''
{
    "sections": {
      "features": [
        {
          "name": "DepressedMood",
          "definition": "Victim was perceived by self or others to be depressed at the time of the injury.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Only code this variable when the victim had a depressed mood at the time of injury. There does NOT need to be a clinical diagnosis, and there does not need to be any indication that the depression directly contributed to the death. Other words that can trigger coding this variable besides 'depressed' are sad, despondent, down, blue, low, unhappy, etc. Words that should not trigger coding this variable are agitated, angry, mad, anxious, overwrought, etc. If the victim has a known clinical history of depression but had no depressive symptoms at the time of the incident, this variable should NOT be selected. Depressed mood should not be inferred by the coder based on the circumstances (e.g., because the person reports a bankruptcy); rather it must be noted in the record."
        },
        {
          "name": "MentalIllnessTreatmentCurrnt",
          "definition": "Currently in treatment for a mental health problem or substance abuse problem.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "This should be coded 'Yes' if the victim was in current treatment (e.g., had a current prescription for a psychiatric medication, saw a mental health professional within the past two months, or participated in treatment for substance abuse such as outpatient treatment or Alcoholics Anonymous) at the time of the injury. Treatment includes seeing a psychiatrist, psychologist, medical doctor, therapist, or other counselor (including religious or spiritual counselors) for a mental health or substance abuse problem; receiving a prescription for an antidepressant or other psychiatric medicine; attending anger management classes; residing in an inpatient, group home, or halfway house facility for mental health or substance abuse problems; or attending alcohol or narcotics anonymous. Do not code this circumstance based only on a positive toxicology test for psychiatric medications (such as antidepressants). There must also be some indication that the victim was actually being treated for a mental health condition, such as a current prescription, the report of a family member, etc. Note that a diagnosis does not imply that treatment was received. A victim may have been out of compliance with treatment for a diagnosed condition. If you code 'Yes' for MentalIllnessTreatmentCurrnt you MUST code 'Yes' for HistoryMentalIllnessTreatmnt."
        },
        {
          "name": "HistoryMentalIllnessTreatmnt",
          "definition": "History of ever being treated for a mental health or substance abuse problem.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "The variable indicates whether the victim was noted as ever having received treatment (e.g., had a current prescription for a psychiatric medication, saw a mental health professional within the past two months, or participated in a self-help program such as Alcoholics Anonymous) for a mental health problem (including alcohol and other substance abuse problems), either at the time of death or in the past. If a victim is in current treatment, by definition, ever in treatment should be endorsed as well. Do not code this circumstance based only on a positive toxicology test for psychiatric medications (such as antidepressants); there must also be some indication that the victim was actually treated for a mental health condition, such as a current prescription or the report of a family member, etc. Note that a diagnosis does not imply that treatment was received, as a victim may have been out of compliance with treatment for a diagnosed condition."
        },
        {
          "name": "SuicideAttemptHistory",
          "definition": "Victim has a history of attempting suicide before the fatal incident.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' if the victim was known to have made previous suicide attempts before the fatal incident, regardless of the severity of those attempts or whether any attempts resulted in injury. Per the CDC uniform definition of suicide attempt, which describes it as a non-fatal, self-directed, potentially injurious behavior with any intent to die as a result of the behavior (which may or may not result in injury), the victim must engage in a potentially injurious behavior, defined as one that has the ability to cause injury and/or death. For example, pulling the trigger on a firearm during Russian roulette is considered potentially injurious, regardless of whether the weapon fires when the victim pulled the trigger; therefore, code as 'Yes.' Similarly, swallowing a lethal dose of pills and then calling 911 is also considered potentially injurious, so code as 'Yes.' If the victim made a suicidal gesture (such as placing ligature around their neck, standing on a bridge preparing to jump, or holding a gun to their head) but was stopped before taking action (e.g., did not pull the trigger after talking to family or was pulled from the bridge by law enforcement before jumping), this behavior should be considered a suicide attempt, and code as 'Yes.' Evidence of a history of suicide attempts may include self-report and documentation or reports from others, including family, friends, and health professionals."
        },
        {
          "name": "SuicideThoughtHistory",
          "definition": "Victim had a history of suicidal thoughts or plans. Disclosure of suicidal thoughts or plan can be verbal, written or electronic.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Use this code for victims who have at any time in their life expressed suicidal thoughts or plans, regardless of whether these thoughts and/or plans were disclosed close to the time of the suicide. Suicidal ideation can be expressed directly (e.g., 'I am thinking of killing myself') or indirectly (e.g., 'I don’t know if I want to go on living'). When the timing is unclear (e.g., timing not mentioned) or if the suicidal thoughts were described as occurring in the 'past,' 'a few years ago,' or 'just,' the history of suicidal thoughts should be coded as 'Yes.' Additionally, code 'Recently disclosed suicidal thoughts/plans' if the victim disclosed suicidal thoughts and/or plans close to the time (within one month) of the suicide. Code 'No' for previous suicide attempts if the victim did not disclose suicidal thoughts or plans."
        },
        {
          "name": "SubstanceAbuseProblem",
          "definition": "Victim had alcohol dependence or alcohol problem or other illicit or prescription drug abuse problem.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code 'Yes' for 'SubstanceAbuseProblem' if the victim was perceived to have an alcohol-related issue or addiction, regardless of whether it directly contributed to the death; this includes those participating in rehabilitation programs or self-help groups, even if currently sober. However, do not code for past alcohol issues that have resolved or if the victim used alcohol shortly before the incident without evidence of dependence. Similarly, use code 'Yes' for 'SubstanceAbuseProblem' if the victim was perceived to have a drug problem or addiction, including illicit drugs or prescription medication abuse, regardless of direct contribution to the death. Participation in rehabilitation programs qualifies for coding 'Yes,' even if the individual is currently clean. A history of drug abuse suffices for this coding unless the victim is explicitly noted as no longer using drugs. Chronic or problematic marijuana use can be coded as 'Yes,' but if it was used at the time of the incident without evidence of abuse, it should be coded as 'No'."
        },
        {
          "name": "MentalHealthProblem",
          "definition": "Current mental health problem.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code a victim as 'Yes' for 'MentalHealthProblem' if they are identified as currently having a mental health issue, regardless of whether it contributed to their death. This includes disorders listed in the Diagnostic and Statistical Manual of Mental Disorders, Fifth Edition (DSM-5), excluding substance dependencies, and encompasses conditions such as major depression, schizophrenia, generalized anxiety disorder, neurodevelopmental disorders (like intellectual disability, autism, and ADHD), eating disorders, personality disorders, and organic mental disorders (including Alzheimer’s). Indicate 'Yes' if the source document mentions that the victim was receiving treatment for a mental health issue, even if the specifics are unclear. Past treatment can justify a 'Yes' unless it is explicitly noted that the problem has been resolved; however, do not base this coding solely on toxicology results showing psychiatric medication without evidence of ongoing treatment, such as a current prescription or corroboration from family members."
        },
        {
          "name": "DiagnosisAnxiety",
          "definition": "The victim is diagnosed with anxiety disorder.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' for 'DiagnosisAnxiety' if they are identified as currently having anxiety disorder regardless of whether it contributed to their death. Past treatment can justify a 'Yes' unless it is explicitly noted that the problem has been resolved; however, do not base this coding solely on toxicology results showing psychiatric medication without evidence of ongoing treatment, such as a current prescription or corroboration from family members."
        },
        {
          "name": "DiagnosisDepressionDysthymia",
          "definition": "The victim is diagnosed with depression or dysthymia.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' for 'DiagnosisDepressionDysthymia' if they are identified as currently having depression or dysthymia regardless of whether it contributed to their death. Past treatment can justify a 'Yes' unless it is explicitly noted that the problem has been resolved; however, do not base this coding solely on toxicology results showing psychiatric medication without evidence of ongoing treatment, such as a current prescription or corroboration from family members."
        },
        {
          "name": "DiagnosisBipolar",
          "definition": "The victim is diagnosed with bipolar disorder.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' for 'DiagnosisBipolar' if they are identified as currently having bipolar disorder regardless of whether it contributed to their death. Past treatment can justify a 'Yes' unless it is explicitly noted that the problem has been resolved; however, do not base this coding solely on toxicology results showing psychiatric medication without evidence of ongoing treatment, such as a current prescription or corroboration from family members."
        },
        {
          "name": "DiagnosisAdhd",
          "definition": "The victim is diagnosed with attention deficit hyperactivity disorder.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' for 'DiagnosisAdhd' if they are identified as currently having attention deficit hyperactivity disorder regardless of whether it contributed to their death. Past treatment can justify a 'Yes' unless it is explicitly noted that the problem has been resolved; however, do not base this coding solely on toxicology results showing psychiatric medication without evidence of ongoing treatment, such as a current prescription or corroboration from family members."
        },
        {
          "name": "IntimatePartnerProblem",
          "definition": "Problems with a current or former intimate partner appear to have contributed to the suicide or undetermined death.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' if the victim was experiencing issues with a current or former intimate partner at the time of the incident, such as divorce, break-up, argument, jealousy, conflict, or discord, and if these issues appear to have contributed to the death. An intimate partner is defined as a current or former girlfriend/boyfriend, dating partner, ongoing sexual partner, or spouse; it does not include transactional relationships where intimacy is exchanged for money or goods. There must be clear evidence of an intimate relationship, which excludes situations based solely on attraction or unreciprocated feelings. The definition does not require sexual intimacy and includes same-sex partners. Additionally, while relationship difficulties must be evident, caregiving burdens for an ill spouse or partner should not be classified as an intimate partner problem unless relationship issues are also indicated. Phrases like 'victim was having relationship problems' can be interpreted as evidence of intimate partner problems."
        },
        {
          "name": "FamilyRelationship",
          "definition": "Victim had relationship problems with a family member (other than an intimate partner) that appear to have contributed to the death.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code as 'Yes' if, at the time of the incident, the victim was facing a relationship problem with a family member other than an intimate partner (such as a child, mother, or in-law), and this problem appears to have contributed to the death. This variable does not encompass issues related to the broader family environment that do not specifically pertain to the victim's relationship with a family member, such as the stress of caregiving for a sick relative. For example, a victim who is despondent over an argument with their parents and subsequently dies by suicide would qualify, as would a victim who is killed during a fight with an estranged brother at a family reunion. However, if the report indicates that the victim was 'having relationship problems,' it should be assumed to pertain to intimate partner issues rather than those involving other friends or family. Additionally, this code should not be used for custody disputes involving a child unless the dispute affects the relationship between the parent and child. The narrative should include a clear explanation of the relationship problem and identify the specific family member involved."
        },
        {
          "name": "Argument",
          "definition": "An argument or conflict led to the victim’s death.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "This variable identifies violent deaths where a specific argument is perceived to be related to the death. To code this variable as 'Yes,' there must be a clear argument or disagreement that directly correlates with the violent death, such as an argument over money, a relationship issue, or an insult. For instance, if a verbal dispute escalates into a physical confrontation, such as a bar argument leading to a fatal fight, it should be coded as 'Yes.' Similarly, suicides that follow specific arguments, like a child arguing with a parent before taking their life or a victim dying by suicide after being expelled from school, should also be coded positively. Chronic arguments can also qualify if a particular dispute is mentioned in the context of the death. Conversely, a general relationship problem without a specific argument does not meet the criteria, nor do ongoing conflicts unless a specific incident is noted. Cases involving a history of abuse by a suspect should also be coded as 'No' unless a specific argument related to the death is documented. Furthermore, deaths occurring during criminal activities not motivated by prior arguments, killings by law enforcement during duty, or fatalities resulting from self-defense scenarios should all be coded as 'No.'"
        },
        {
          "name": "SchoolProblem",
          "definition": "Problems at or related to school appear to have contributed to the death.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code 'Yes' if the victim was facing specific issues at school, such as poor grades, conflicts with teachers, bullying, social exclusion, detention or suspension, or performance pressures, and these problems seem to have contributed to their death. It is important that there is a clear link between the victim's school-related difficulties and the circumstances surrounding their death. Conversely, if the only mention of the victim’s academic performance is low grades without any indication of distress or specific problems associated with them—such as merely receiving a failing grade—then this should be coded as 'No.' The emphasis is on the presence of a significant issue rather than a mere mention of low academic performance."
        },
        {
          "name": "RecentCriminalLegalProblem",
          "definition": "Criminal legal problem(s) appear to have contributed to the death.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "Code 'Yes' if the victim was experiencing criminal legal problems at the time of the incident, such as facing a recent or impending arrest, being pursued by law enforcement, or having an upcoming court date, and these issues appear to have contributed to their death. This includes military offenses, such as being Absent Without Leave. It is important to distinguish criminal legal problems from civil legal issues; the former are those actions deemed harmful to society and are prohibited by law, with consequences enforced by the government, such as driving under the influence. Simply committing a crime is not enough to warrant a 'Yes' code; there must be clear evidence that the victim was facing significant legal repercussions that are linked to the circumstances of their death."
        },
        {
          "name": "SuicideNote",
          "definition": "Victim left a suicide note (or other recorded communication). Note can be written or electronic.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "A will or a folder of financial documents near the victim does not qualify as a suicide note. If records indicate that the individual left a note, it can generally be inferred as a suicide note unless there is evidence suggesting it served another purpose. A suicide note can take various forms and does not need to be written on paper; messages sent via email, text, voicemail, or even inscribed on objects like walls or tables are all valid. However, phone calls, including 911 calls, do not count, as they lack durability. Notably, a suicide note does not have to explicitly express the desire to die; messages intended to warn others about hazardous conditions can also be included. Texts or electronic messages sent immediately before the suicide should be classified as suicide notes if there was no intervening time, and therefore code as 'Yes.' Summarizing the content of the suicide note in the narrative can provide valuable context, but it should be done without verbatim quotes or identifying information, focusing instead on themes relevant to the suicide."
        },
        {
          "name": "SuicideIntentDisclosed",
          "definition": "Victim disclosed to another person their thoughts and/or plans to die by suicide within the last month. Disclosure of suicidal thoughts or plan can be verbal, written or electronic.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": "This variable helps identify suicides for which opportunities to intervene and prevent the death may have been present near the time of the suicide and is also useful for exploring the association between stated intent and actual death. Code as 'Yes' if the victim had disclosed suicidal thoughts or plans to another person recently or within the last month, whether explicitly (e.g., 'I have been thinking about suicide lately' or 'I plan to go to my cabin with my gun and never come back') or indirectly (e.g., 'I know how to put a permanent end to this pain'). Include in the narrative any available details about whom the intent was disclosed to, how long before the death the intent was disclosed, and what was said during the disclosure. Code as 'Yes' if there was an opportunity to intervene between the time the person disclosed intent and the injury event. Do not code this variable if the victim disclosed the intention to kill themselves only at the moment of the suicide (i.e., when there was no opportunity to intervene to stop the suicide), such as sending an email or text message right before the victim shot herself, as this would be considered a suicide note. Additionally, do not endorse this variable if the victim had talked about suicide sometime in the distant past but had not recently disclosed a current intent to die by suicide to anyone; this should be coded as 'History of disclosed suicidal thoughts/plans.' A separate suicide attempt by the victim within a month of the suicide should be coded as 'Yes,' and in this case, 'History of suicide attempts' should also be coded as 'Yes.' If the timing of the victim's disclosure of suicidal intent is unclear (e.g., recently or some time ago) or not mentioned, use the following rules to code these cases: code 'Yes' if the narrative states the victim 'just' or 'recently' told someone about their suicidal intent; if the record indicates disclosure of intent but is unclear about the timeframe (i.e., does not mention it at all), code as 'Yes.' However, if law enforcement or coroner/medical examiner reports indicate disclosure of intent in the past but state that there was no disclosure for the current incident, code this as 'No.'"
        },
        {
          "name": "DisclosedToIntimatePartner",
          "definition": "Intent was disclosed to a previous or current intimate partner.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": ""
        },
        {
          "name": "DisclosedToOtherFamilyMember",
          "definition": "Intent was disclosed to another family member.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": ""
        },
        {
          "name": "DisclosedToFriend",
          "definition": "Intent was disclosed to a friend.",
          "responseOptions":[
            {"0": "No, Not Available, Unknown"},
            {"1": "Yes"}
          ],
          "instruction": ""
        },
        {
          "name": "InjuryLocationType",
          "definition": "The type of place at which the injury occurred.",
          "responseOptions":[
            {"1": "House, apartment"},
            {"2": "Motor vehicle (excluding school bus and public transportation)"},
            {"3": "Natural area (e.g., field, river, beaches, woods)"},
            {"4": "Park, playground, public use area"},
            {"5": "Street/road, sidewalk, alley"},
            {"6": "Other"}
          ],
          "instruction": ""
        },
        {
          "name": "WeaponType1",
          "definition": "Type of weapon or means used to inflict the fatal injury.",
          "responseOptions": [
            {"1": "Blunt instrument"},
            {"2": "Drowning"},
            {"3": "Fall"},
            {"4": "Fire or burns"},
            {"5": "Firearm"},
            {"6": "Hanging, strangulation, suffocation"},
            {"7": "Motor vehicle including buses, motorcycles"},
            {"8": "Other transport vehicle, eg, trains, planes, boats"},
            {"9": "Poisoning"},
            {"10": "Sharp instrument"},
            {"11": "Other (e.g., Taser, electrocution, nail gun, exposure to environment/weather)"},
            {"12": "Unknown"}]
          ,
          "instruction": "Weapon type reports the general category of means used to inflict fatal injuries, encompassing objects (such as knives), actions (like jumping from heights), hostile environments (such as fire or water), and even neglect in cases involving vulnerable individuals. Code only the primary weapon responsible for death, prioritizing the weapon that inflicted the most force or deprived the victim of essential needs like oxygen. 'Sharp instrument' includes not just knives but also items like razors and broken glass, while 'blunt instrument' refers to clubs or blunt force trauma. Carbon monoxide poisoning is categorized as a poisoning, and if the carbon monoxide poisoning results from a fire, code as 'fire or burns.' Deaths involving non-toxic asphyxiant gases are classified as suffocation, and 'Other' also includes fists and feet used in violence, though manual strangulation is categorized separately. Falls are coded based on the circumstances, differentiating between being pushed (other) and intentional jumps (falls). In cases where deaths are attributed to external forces but the victim also has lethal levels of substances in their system, prioritize coding the external force over the poisoning. For deaths involving falls into water, classify the weapon type based on whether drowning or impact injuries were the cause of death."
        }
      ]
    }
  }
'''

# %%
data_dict = json.loads(json_data)

# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments

label_columns = [
    'DepressedMood',
    'MentalIllnessTreatmentCurrnt',
    'HistoryMentalIllnessTreatmnt',
    'SuicideAttemptHistory',
    'SuicideThoughtHistory',
    'SubstanceAbuseProblem',
    'MentalHealthProblem',
    'DiagnosisAnxiety',
    'DiagnosisDepressionDysthymia',
    'DiagnosisBipolar',
    'DiagnosisAdhd',
    'IntimatePartnerProblem',
    'FamilyRelationship',
    'Argument',
    'SchoolProblem',
    'RecentCriminalLegalProblem',
    'SuicideNote',
    'SuicideIntentDisclosed',
    'DisclosedToIntimatePartner',
    'DisclosedToOtherFamilyMember',
    'DisclosedToFriend'
]



# Prepare texts and labels
texts = training_data['NarrativeCME'].tolist()
labels =training_labels[label_columns].values

# Tokenize texts
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
from sklearn.model_selection import train_test_split

# Split the data
texts_train, texts_val, labels_train, labels_val = train_test_split(
    texts,
    labels,
    test_size=0.2,       # Use 10% of data for validation
    random_state=42      # Set a random seed for reproducibility
)

# %%
# Tokenize training texts
train_encodings = tokenizer(
    texts_train,
    truncation=True,
    padding=True,
    max_length=512
)

# Tokenize validation texts
val_encodings = tokenizer(
    texts_val,
    truncation=True,
    padding=True,
    max_length=512
)

# %%
# Create dataset
class MultiLabelDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx], dtype=torch.float)
        return item

    def __len__(self):
        return len(self.labels)

# Create dataset instances
train_dataset = MultiLabelDataset(train_encodings, labels_train)
val_dataset = MultiLabelDataset(val_encodings, labels_val)



# Initialize model
model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels=len(label_columns),
    problem_type='multi_label_classification'
)

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=10,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    eval_strategy="epoch",         # Updated parameter name
    save_strategy="epoch",         # Set to match eval_strategy
    logging_dir='./logs',
    logging_steps=10,
    metric_for_best_model='mean_f1',
    greater_is_better=True,
    load_best_model_at_end=True,
    save_total_limit=2,
)

# Define compute_metrics function as before
from sklearn.metrics import f1_score
import numpy as np

def compute_metrics(p):
    preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    labels = p.label_ids

    # Apply sigmoid to get probabilities
    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(torch.tensor(preds))

    # Binarize predictions at threshold 0.5
    y_pred = (probs >= 0.5).numpy()

    # Convert labels to integer type
    y_true = labels.astype(int)

    # Initialize list to store F1 scores
    f1_scores = []

    # Calculate F1 score for each binary variable
    for i in range(y_true.shape[1]):
        f1 = f1_score(y_true[:, i], y_pred[:, i])
        f1_scores.append(f1)

    # Compute the average F1 score
    mean_f1 = np.mean(f1_scores)

    # Return as a dictionary (Trainer requires a dict)
    return {
        'mean_f1': mean_f1,
    }



# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,  # Use separate validation set
    compute_metrics=compute_metrics
)

# Train the model
trainer.train()

# Save the model
trainer.save_model('./fine_tuned_model')
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# ...
